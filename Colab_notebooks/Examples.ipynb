# %%
def money(first_money,profit):
  last_money = first_money + (first_money * profit)  # The money reach the amount at the end of first day 
  last_money += (last_money * profit)  # The money reach the amount at the end of second day 
  last_money += (last_money * profit)  # The money reach the amount at the end of third day 
  last_money += (last_money * profit)  # The money reach the amount at the end of fourth day 
  last_money += (last_money * profit)  # The money reach the amount at the end of fifth day 
  last_money += (last_money * profit)  # The money reach the amount at the end of sixth day 
  last_money += (last_money * profit)  # The money reach the amount at the end of seventh day 

  return last_money
print(money(1000, 0.07))
# Out:
# 1605.78147647843

# %%
word_1 = input("Enter first word :")
word_2 = input("Enter second word :")
for i in word_1:
  for n in word_2:
    if i == n:
      print(n)
# Out:
# Enter first word :zahire
# Enter second word :kahire
# a
# h
# i
# r
# e

# %%
word = input("Lutfen kelimeyi giriniz :")
letter = input("Lutfen indexi bulunacak harfi giriniz :")
ind_num = 0
for i in word:
  if i == letter:
    break
  else:
    ind_num += 1
print(f"{word} kelimesindeki {letter} harfinin index numarasi : {ind_num}")
# Out:
# Lutfen kelimeyi giriniz :okul
# Lutfen indexi bulunacak harfi giriniz :l
# okul kelimesindeki l harfinin index numarasi : 3

# %%
sayaç = 0  
i_num = "" #  index numaralarını burada saklayalım
ifade = input("bir kelime ya da cümle giriniz: ") 
ara = input("aramak istediğiniz harfi giriniz: ")
for i in ifade:
    if i == ara:
        i_num += str(ifade.index(ara, sayaç))+", "
        #print(f"{ifade} ifadesinde {ara} harfinin index numaraları {ifade.index(ara,sayaç)}")
    sayaç += 1
print("{} ifadesinde {} harfinin index numaraları: {}".format(ifade, ara, i_num))
# Out:
# bir kelime ya da cümle giriniz: bugün nasılsın
# aramak istediğiniz harfi giriniz: n
# bugün nasılsın ifadesinde n harfinin index numaraları: 4, 6, 13,

# %%
6

# %%
for i in range(6):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
      f_money = 1000
      pft = 0.07
      for i in range(7): 
       f_money += (f_money * pft)  # The money reach the amount at the end of first day 
      print(f_money)
# Out:
# 1605.78147647843

# %%
def money(f_money,pft):
     for i in range(7): 
       f_money += (f_money * pft)  # The money reach the amount at the end of first day 
     return f_money   
print(money(1000, 0.07))
# Out:
# 1605.78147647843

# %%
# -*- coding: utf-8 -*-
"""
Created on Fri Mar 19 20:45:55 2021
​
@author: Elif & Zeynep
"""
while True:
    age = input("Please input your age: ")
  # <--- Begining of the numeric control --->  
    try:  
        
        if not age:
            print("Age can't be blank")
        age = int(age)
        if age < 0:
            print("Please input a valid age")
            continue
        elif 0 < age <75:
            age = False
        elif 75 <= age < 100:
            age = True
        else:
            print("Please input a valid age!!!")
            continue
​
        
                
    except ValueError:
        print("Please input your age as numeric")
        continue
    # <--- End of the numeric control --->
    
    chronicle = input("Do you have a severe chronic disease? Yes or No : ")
    if not chronicle:
        print("Please, answer, can't be blanked")
    elif chronicle.lower() == "yes":
        chronicle = True
    elif chronicle.lower() == "no":
        chronicle = False
    else:
        print("Please write your answer. As Yes or No ")
        continue
    
    immune = input("Is your immune system too weak? Yes or No: ")
    if not immune:
        print("Please, answer, can't be blanked")
    elif immune.lower() == "yes":
        immune = True
    elif immune.lower() == "no":
        immune = False
    else:
        print("Please write your answer. As Yes or No")
        continue
    
    if age and immune and chronicle:
        print("You are in group of High Risk Death!!! Wear a Mask! Save Your Life! ")
    elif age and immune or age and chronicle or immune and chronicle:
        print("You are in medium risk group. Please keep on wearing a mask!")
    else:
        print("You are not in Risk Group but wear a mask and keep social distance")

# %%
text = 'the better the family, the better the socienty'
l_text = list(text)
print(l_text)
r_text = l_text
r_text[0] = l_text[0].replace('t','T')
r_text[4] = l_text[4].replace('b','B')
r_text[11] = l_text[11].replace('t','T')
r_text[15] = l_text[15].replace('f','F')
r_text[23] = l_text[23].replace('t','T')
r_text[27] = l_text[27].replace('b','B')
N_text= ''
for i in range(len(r_text)):
  N_text += r_text[i]
print(N_text)

# %%
import time
sifre =4434
def bekle(sn):
    print("{}sn beklemeniz gerekmektedir!!!".format(sn))
    while sn>=0:
        print(sn,end=",")
        time.sleep(1)
        sn=sn-1
def parolaiste():
    global parola
    parola=int(input("4 haneli kilit şifresini giriniz:"))
while True:
    parolaiste()
    sayac=1
    if parola==sifre:
        print("GİRİŞ DOĞRULANDI.")
        break
    elif parola!=sifre:
        print("HATALI ŞİFRE")
        while True:
            sayac+=1
            parolaiste()
            if parola==sifre:
                print("GİRİŞ DOĞRULANDI")
                sayac=1
                break
            elif sayac>=0 and sayac<3:
                print("HATALI ŞİFRE")
            elif sayac>=3 and sayac<5:
                print("HATALI ŞİFRE")
                print("3 ve daha fazla hatalı şifre girdiniz. 3 sn beklemeniz gerekmektedir!")
                bekle(3)
                print()
            elif sayac>=5 and sayac<10:
                print("HATALI ŞİFRE")
                print("5 ve daha fazla hatalı şifre girdiniz. 10 sn beklemeniz gerekmektedir!")
                bekle(10)
                print()
            elif sayac>=10:
                print("HATALI ŞİFRE")
                print("10 ve daha fazla hatalı şifre girdiniz. 30 sn beklemeniz gerekmektedir!")
                bekle(30)
                print()
    break
