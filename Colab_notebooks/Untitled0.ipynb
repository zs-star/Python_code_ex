# %%
print(print.__doc__)
# Out:
# print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
# Prints the values to a stream, or to sys.stdout by default.
# Optional keyword arguments:
# file:  a file-like object (stream); defaults to the current sys.stdout.
# sep:   string inserted between values, default a space.
# end:   string appended after the last value, default a newline.
# flush: whether to forcibly flush the stream.

# %%
print(map.__doc__)
# Out:
# map(func, *iterables) --> map object
#
# Make an iterator that computes the function using arguments from
# each of the iterables.  Stops when the shortest iterable is exhausted.

# %%
x = 1
y = 2
z = 3
print(x, y, z)
# Out:
# 1 2 3

# %%
1!=2
# Out:
# True

# %%
1nası = 5
# Out:
#   File "<ipython-input-5-ad542b3b1580>", line 1
#     1nası = 5
#         ^
# SyntaxError: invalid syntax

# %%
last name
# Out:
#   File "<ipython-input-6-9ee3d3bab6ee>", line 1
#     last name
#             ^
# SyntaxError: invalid syntax

# %%
sır() =1
# Out:
#   File "<ipython-input-7-59035eac6ffa>", line 1
#     sır() =1
#             ^
# SyntaxError: can't assign to function call

# %%
print(startswith.__doc__)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-03da65fe4e30> in <module>()
# ----> 1 print(startswith.__doc__)
#
# NameError: name 'startswith' is not defined

# %%
name = "Zehra"
user_name = input("Enter the your name please: ").title()
if user_name == name:
   print("Hello, {}! The password is : W@12,".format(name))
else:
  print("Hello, {}! See you later.".format(user_name))
# Out:
# Enter the your name please: zehra
# Hello, Zehra! The password is : W@12,
