# %%
text = "{}! I am a {} programmer and I {} Clarusway.".format("Hello", "new", "love")
print(text)
# Out:
# Hello! I am a new programmer and I love Clarusway.

# %%
# Assignment-008/1 (The Most Frequent Element)
list_b = [53, 24, 57, 33, 24, 51, 55, 85, 33, 26, 85, 98, 33, 51, 33]
print("Given List:\n", list_b)
mfe = max(set(list_b), key=list_b.count)
print(mfe)
print("The most frequent number is", mfe, "and it was", list_b.count(mfe), "times repeated.")
# Out:
# Given List:
#  [53, 24, 57, 33, 24, 51, 55, 85, 33, 26, 85, 98, 33, 51, 33]
# 33
# The most frequent number is 33 and it was 4 times repeated.

# %%
print(max.__doc__)
# Out:
# max(iterable, *[, default=obj, key=func]) -> value
# max(arg1, arg2, *args, *[, key=func]) -> value
#
# With a single iterable argument, return its biggest item. The
# default keyword-only argument specifies an object to return if
# the provided iterable is empty.
# With two or more arguments, return the largest argument.

# %%
numbers = range(1, 11)
odd_n = list(numbers)[1::2]
print(odd_n)
# Out:
# [2, 4, 6, 8, 10]

# %%
print(5, 3)
# Out:
# 5 3

# %%
numbers = [1,26,3,4]
a = numbers 
numbers.sort()

a
# Out:
# [1, 3, 4, 26]

# %%
list_1 = ["@","*-","False"]
list_1.sort()
list_1
# Out:
# ['*-', '@', 'False']

# %%
a = "zah"
a += "ire"
print (a)
# Out:
# zahire

# %%
warning = 'You must quit smoking!'

print(len(warning))
# Out:
# 22

# %%
mixed_list = [11, 'Joseph', False, 3.14, None, [1, 2, 3]]
mixed_list.del(0)
mixed_list
# Out:
#   File "<ipython-input-9-b5e5fc61d478>", line 2
#     mixed_list.del(0)
#                  ^
# SyntaxError: invalid syntax

# %%
_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-dcbd92299021> in <module>()
# ----> 1 __doc__.pop()
#
# AttributeError: 'str' object has no attribute 'pop'

# %%
my_list = ['Joseph', 'Clarusway', 2020]
new_list1 = list(my_list)  
new_list2 = [my_list]  
print(new_list1)
print(len(new_list1)) 
print(new_list2)
print(len(new_list2))
# Out:
# ['Joseph', 'Clarusway', 2020]
# 3
# [['Joseph', 'Clarusway', 2020]]
# 1

# %% [markdown]
# word = 'clarusway'
# n = 3
# front = 'cla'
# back = 'usway'
# print(front + back)

# %%
list_1 = []
list_1.append(1)
list_1.append(2)
list_1.append(3)
list_1.append(4)
print(list_1)
# Out:
# [1, 2, 3, 4]

# %%
str = '\\\\'
print(str)
# Out:
# \\

# %%
a =3
b =4
print("{} + {} ' nin toplamı {}' dir".format(a,b,a+b))
# Out:
# 3 + 4 ' nin toplamı 7' dir

# %%
word = 'clarusway'
n = 3
front = 'cla'
back = 'usway'
print(front + back)
# Out:
# clausway

# %%
text = "{:.2f},{:.3f},{:.4f}".format(3.1463,5.367,7.324567)
print(text)
# Out:
# 3.15,5.367,7.3246

# %%
text = "{:<20}"{:>20}".format("clarusway","candır")
text

#print(text)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-7b311ac8cd55> in <module>()
# ----> 1 text = "{:<20}{:^10}{:>20}".format("clarusway","candır")
#       2 text
#       3
#       4 #print(text)
#
# IndexError: tuple index out of range

# %%
"{:>10.3}".format(3.17467562784)
# Out:
# '      3.17'

# %%
"{:^20}".format("test")
# Out:
# '        test        '

# %%
print('feeliNGS'.title())
# Out:
# Feelings

# %%
bool = not 0 and "write me" 
print (bool)
# Out:
# write me

# %%
warning = 'You must quit smoking!'

print(len(list(warning)))
# Out:
# 22

# %%
city = ['New York', 'London', 'Istanbul', 'Seoul', 'Sydney']
print(city[0])
# Out:
# New York

# %%
city[0] = 2
print(city)
# Out:
# [2, 'London', 'Istanbul', 'Seoul', 'Sydney']

# %%
type(city[0])
# Out:
# int

# %%
city[0:2] = 'al'
print(city)
# Out:
# ['a', 'l', 'i', 'Istanbul', 'Seoul', 'Sydney']

# %%
city.index('a')
# Out:
# 0

# %%
city.del(0)
# Out:
#   File "<ipython-input-13-f07c302c1242>", line 1
#     city.del('a')
#            ^
# SyntaxError: invalid syntax

# %%
print(format("Welcome", "10s"), end = '#')
print(format(111, "5d"), end = '#')
print(format(924.656, "3.3f"))
# Out:
# Welcome   #  111#924.656

# %%
flowers = ['Rose', 'Orchid', 'Tulip']
count1 = len(flowers)
count2 = 0

while count1>0 :
    print(flowers[count2])
    count1 -= 1
    count2 += 1
# Out:
# Rose
# Orchid
# Tulip

# %%
for i in {'n1' : 'one', 'n2' : 'two'} : print(i)
# Out:
# n1
# n2

# %%
iterable = [1, 2, 3, 4]
for i in iterable:
 print(i**2)
# Out:
# 1
# 4
# 9
# 16

# %%
#times = int(input("How many times should I say 'I love you'"))

for i in range(int(input("How many times should I say 'I love you'"))):
    print('I love you')
# Out:
# How many times should I say 'I love you'3
# I love you
# I love you
# I love you

# %%
math_mark = int(input('Please enter the mark: '))
if math_mark <= 44:
  print("F (Failed)")
elif math_mark <= 59 and math_mark >=45: 
    print("D (Not Bad)")
elif math_mark <= 69 and math_mark >=60: 
    print("C (Medium)")
elif math_mark <= 84 and math_mark >=70: 
    print("B (Good)")
elif math_mark <= 100 and math_mark >=85: 
    print("A (Excellent)")
# Out:
# Please enter the mark: 20
# F (Failed)

# %%
a  = 998
if a >= 999 :
    print(a ** 0)  

else :
    print(a * 2)
# Out:
# 1996

# %%
number = int(input('Please enter a number: '))
i =0 
while i**2 < number**2:
  print(i**2)
  i += 1
# Out:
# Please enter a number: 3
# 0
# 1
# 4

# %%
sample_list = [{"section":5, "topic":2}, 'clarusway', [1, 4], 2020, 3.14, 1+618j, False, (10, 20)]
for i in sample_list:
  print("The type of {} is {}.".format(i,type(i)))
# Out:
# The type of {'section': 5, 'topic': 2} is <class 'dict'>.
# The type of clarusway is <class 'str'>.
# The type of [1, 4] is <class 'list'>.
# The type of 2020 is <class 'int'>.
# The type of 3.14 is <class 'float'>.
# The type of (1+618j) is <class 'complex'>.
# The type of False is <class 'bool'>.
# The type of (10, 20) is <class 'tuple'>.

# %%
numbers = input("Enter the numbers :")
numbers_count = numbers.split(",")[0]
numbers_list =  numbers.split(",")[1]

print(numbers.split(",")[1])
# Out:
# Enter the numbers :6,7 8  9 10
# 7 8  9 10

# %%
list_main = ["eat", "tea", "tan", "ate", "nat", "bat"]
anagram_dict = dict()
for i in list_main:
    key = tuple(sorted(i))
    anagram_dict.setdefault(key,[]).append(i)
    print(anagram_dict)
list(anagram_dict.values())
# Out:
# {('a', 'e', 't'): ['eat']}
# {('a', 'e', 't'): ['eat', 'tea']}
# {('a', 'e', 't'): ['eat', 'tea'], ('a', 'n', 't'): ['tan']}
# {('a', 'e', 't'): ['eat', 'tea', 'ate'], ('a', 'n', 't'): ['tan']}
# {('a', 'e', 't'): ['eat', 'tea', 'ate'], ('a', 'n', 't'): ['tan', 'nat']}
# {('a', 'e', 't'): ['eat', 'tea', 'ate'], ('a', 'n', 't'): ['tan', 'nat'], ('a', 'b', 't'): ['bat']}
# [['eat', 'tea', 'ate'], ['tan', 'nat'], ['bat']]
