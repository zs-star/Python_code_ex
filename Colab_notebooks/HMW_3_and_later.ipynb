# %%
age = input("Are you a cigarette addict older than 75 years old? (Yes/No): ")
chronic = input("Do you have a severe chronic disease? (Yes/No): ")
immune = input("Is your immune system too weak? (Yes/No): ")
age = age.capitalize()
chronic = chronic.capitalize()
immune = immune.capitalize()
if  age == "Yes":
    age = True
else:
    age = False
if  chronic == "Yes": 
    chronic = True 
else:
    chronic = False 
if  immune == "Yes": 
    immune = True 
else:
    immune = False  
risk = age or chronic or immune
if  risk == True:
  print("\nThere is a risk of death")
else:
  print("\nThere is not any risk of death")
# Out:
# Are you a cigarette addict older than 75 years old? (Yes/No): yes
# Do you have a severe chronic disease? (Yes/No): yes
# Is your immune system too weak? (Yes/No): yes
#
# There is a risk of death

# %%
age = input("Are you a cigarette addict older than 75 years old? (True/False): ")
chronic = input("Do you have a severe chronic disease? (True/False): ")
immune = input("Is your immune system too weak? (True/False): ")
age = age.capitalize()
chronic = chronic.capitalize()
immune = immune.capitalize()
risk = age or chronic or immune
print("\nIs there a risk of death: {}".format(risk))
# Out:
# Are you a cigarette addict older than 75 years old? (True/False): TRUE
# Do you have a severe chronic disease? (True/False): FALSE
# Is your immune system too weak? (True/False): fALSE
#
# Is there a risk of death: True

# %%
#Calculate In the Gregorian calendar, three criteria must be taken into account to identify leap years only boolean type
year = input("Enter 4-digit year: ")
leap_y1 = bool(int (year) % 100 ==0) 
leap_y2 =bool(int(year) % 400 == 0) 
leap_y3 =bool(int(year) % 4 == 0)
leap_y = (leap_y3 and not leap_y1) or leap_y2 
print(leap_y)

# %%
#Calculate In the Gregorian calendar, three criteria must be taken into account to identify leap years only type
year = input("Enter 4-digit year: ")
if int(year) % 400 == 0:
  leap_year = True
elif int(year) % 4 == 0:
    if  int (year) % 100 ==0:
       leap_year = False
    else: 
       leap_year = True  
else:
  leap_year = False        
print (leap_year)
# Out:
# Enter 4-digit year: 1972
# True

# %%
numbers = [1, 3, 7, 4, 3, 0, 3, 6, 3]
repeat_max = 0;
for i in numbers:
  repeat = 0
  for j in numbers:
    if i==j:
        repeat += 1
    else:
        repeat += 0 
  if repeat > repeat_max:     
    repeat_max = repeat 
    max_value = i    
print("The most frequent number is {} and it was {} times repeated.".format(max_value,repeat_max))
# Out:
# The most frequent number is 3 and it was 4 times repeated.

# %%
numbers = [1, 3, 7, 4, 3, 0, 3, 6, 3]
repeat_max = 0;
for i in numbers:
  repeat = numbers.count(i)
  if repeat > repeat_max:     
    repeat_max = repeat 
    max_value = i    
print("The most frequent number is {} and it was {} times repeated.".format(max_value,repeat_max))
# Out:
# The most frequent number is 3 and it was 4 times repeated.

# %%
numbers = [1, 3, 7, 4, 3, 0, 3, 6, 3]
dict = {}
for i in numbers:
  dict[i] = numbers.count(i)
max_freq = max(list((dict.values())))
for i in dict:
  if dict[i]== max_freq:
    number_freq=i
text= "The most frequent number is {} and it was {} times repeated.".format(number_freq, max_freq)
print(text)

# %%
numbers = [1, 3, 7, 4, 3, 0, 3, 6, 3] #given the most freguent item simply
count_freq = numbers.count(3)
text= "The most frequent number is {} and it was {} times repeated.".format(numbers[1], count_freq)
print(text)

# %%
numbers = [1, 7, 3, 4, 3, 0, 3, 6, 3]
count_freq=[]
count_freq.append(numbers.count(numbers[0]))
count_freq.append(numbers.count(numbers[1]))
count_freq.append(numbers.count(numbers[2]))
count_freq.append(numbers.count(numbers[3]))
count_freq.append(numbers.count(numbers[4]))
count_freq.append(numbers.count(numbers[5]))
count_freq.append(numbers.count(numbers[6]))
count_freq.append(numbers.count(numbers[7]))
max_freq = max(count_freq)
repeat_number = count_freq.index(max_freq)
text= "The most frequent number is {} and it was {} times repeated.".format(numbers[repeat_number], max_freq)
print(text)
# Out:
# The most frequent number is 3 and it was 4 times repeated.

# %%
# The example of the values (sell-cost value, inventory) and total profit :
costvalue = float(input("Enter the cost price per unit (in dollars) please: "))
sellvalue = float(input("Enter the sell price per unit (in dollars) please: "))
inventory = float(input( "Enter the number of inventory: "))
sales = {
  "cost_value": costvalue,
  "sell_value": sellvalue,
  "inventory": inventory
}
list_sales = list(sales.values())
profit = (list_sales[1]-list_sales[0])*list_sales[2]
print( "The profit will be : {}".format(round(profit)))

# %%
# Formatting payroll
pay_roll = float(input("Enter the amount of payroll please: "))
print("$%.2f"%pay_roll)

# %%
# Task : Find out if the given word is "comfortable words" in relation to the ten-finger keyboard use.
g_word = input("Enter the word to check if it is comfortable word or not: ").lower().strip()
set_word = set(g_word)
left_list = list("qwertasdfgzxcvb")
right_list = list("yuiophjklnm")
diff_r = set_word.difference(left_list) 
diff_l = set_word.difference(right_list)  
output = bool(diff_r) and bool(diff_l) 
if output == False:
  print("{} (uses only right-hand or left-hand fingers)*".format(output))
else: 
 print("{} (uses both hand fingers)*".format(output))
# Out:
# Enter the word to check if it is comfortable word or not:    tester
# False (uses only right-hand fingers)*

# %%
g_word = input("Enter the word to check if it is comfortable word or not: ").lower()
set_word = set(g_word)
left_list = list("qwertasdfgzxcvb")
right_list = list("yuiophjklnm")
diff_l = set_word.intersection(left_list)
diff_r = set_word.intersection(right_list)
output = bool(diff_r) and bool(diff_l)
if bool(diff_r)== False:
    print("{} (uses only left-hand fingers)*".format(output))
elif bool(diff_l)== False:
     print("{} (uses only right-hand fingers)*".format(output))
else:
     print("{} (uses both hand fingers)*".format(output))

# %%
# Find out if a given number is an "Armstrong Number".
number = input("Enter the positive number: ")
if number.isdigit():
  if int(number) >= 0:
      number = int(number)
      print("Let's check if it is Armstrong number or not!")
      length_no = len(str(number))
      sum_no = 0   
      for i in str(number):   
         sum_no += int(i)**length_no 
      if sum_no==number:
         print("{} is an Armstrong number".format(number)) 
      else:
         print("{} is not Armstrong number".format(number)) 
  else:
      print(" It is an invalid entry. Don't use non-numeric, float, or negative values!") 
      
else:
      print(" It is an invalid entry. Don't use non-numeric, float, or negative values!")
# Out:
# Let's check if it is Armstrong number or not!
# 89 is not Armstrong number

# %%
while True :
    number = input("enter a positive number.")
    digits = len(number)
    summ = 0
    if not number.isdigit() :
        print(number, "is invalid entry. enter numberic value!")
    elif int(number) >= 0 :
        for i in range(digits) :
            summ = summ + int(number[i]) ** digits
        if summ == int(number) :
            print(number, "is an Armstrong Number.")
            break
        else :
            print(number, "is not an Armstrong Number.")
            break

# %%
numbers_list = [2,3,4,12,11,2,3,5,12,2]
my_dict = {}
odd_={}
for i in numbers_list:
  if i not in my_dict:
    my_dict[i] = numbers_list.count(i)
    if my_dict[i]%2:
      odd_[i]=my_dict[i]
print(list(odd_.keys()))
# Out:
# [2, 4, 11, 5]

# %%
# Task : Write a program that takes a number from the user and prints the result to check if it is a prime number.
number = input("Enter the number: ")
if number.isdigit():
  if int(number)>=1:
    number = int(number)      
    count = 0
    for i in range(1,number):
      if number%i==0:
        count+=1
    if count>1:
      print("Output: {} is not a prime number".format(number))
    else:
      print("Output: {} is a prime number".format(number)) 
else:
    print("Enter the valid  number")
# Out:
# Output: 19 is a prime number

# %%
n = int(input("Enter a number to check if it is a prime number."))
count = 0
for i in range(1, n+1) :
    if n % i == 0 :
        count += 1
if (n == 0) or (n == 1) or (count >=3) :
    print(n, "is not a prime number.")
else:
    print(n, "is a prime number")

# %%
#Task : Create a list consisting of Fibonacci numbers from 1 to 55 using control flow statements.
my_list = []
i=1
while i<=55:
  my_list.append(i)
  i =sum(my_list[-2:])  
print(my_list)
