# %%
first_name= 'Zahire'
last_name= 'Seymen'
#output='Hello, '+first_name+' '+last_name
output='Hello, {} {}'.format(first_name,last_name)
print(output)
# Out:
# Hello, Zahire Seymen

# %%
first_name= 'Zahire'
last_name= 'Seymen'
#output='Hello, '+first_name+' '+last_name
output='Hello, {0} {1}'.format(first_name,last_name)
print(output)
# Out:
# Hello, Zahire Seymen

# %%
first_name= 'Zahire'
last_name= 'Seymen'
#output='Hello, '+first_name+' '+last_name
output='Hello, {1} {0}'.format(first_name,last_name)
print(output)
# Out:
# Hello, Seymen Zahire

# %%
first_name= 'Zahire'
last_name= 'Seymen'
#output='Hello, '+first_name+' '+last_name
#output='Hello, {1} {0}'.format(first_name,last_name)
output=f'Hello, {first_name} {last_name}'
print(output)
# Out:
# Hello, Zahire Seymen

# %%
last_name='Harrison'
print(last_name[::-1])
# Out:
# nosirraH

# %%
last_name='Harrison'
print(last_name[2:5])
# Out:
# rri

# %%
last_name='Harrison'
print(last_name[-4:])
# Out:
# ison

# %%
text = 'www.clarusway.com'
print(text.endswith('.com'))
print(text.startswith('www.'))
# Out:
# True
# True

# %%
len(text)
# Out:
# 17

# %%
phrase = "myemailaddress@clarusway.com"

print(len(phrase))
print(phrase.startswith("@", 14))
print(phrase.endswith(".", 15, 28))
# Out:
# 28
# True
# False

# %%
len(phrase)
# Out:
# 28

# %%
email = "clarusway@clarusway.com is my e-mail address"
print(email.startswith("@", 9))
print(email.endswith("-", 10, 32))
len(email)
# Out:
# True
# True
# 44

# %%
sentence = "I live and work in Virginia"
title_sentence = sentence.title() 
print(title_sentence)  

changed_sentence = sentence.replace("i", "+")
print(changed_sentence)  

print(sentence)
# Out:
# I Live And Work In Virginia
# I l+ve and work +n V+rg+n+a
# I live and work in Virginia

# %%
source_string = "interoperability"
print(source_string.lstrip("ni"))
# Out:
# teroperability

# %%
print(first_name)
# Out:
# Zahire

# %%
f_name=input('Please enter your first name: ')
l_name=input('Please enter your last name: ')
print('Hello, ' +f_name + ' ' + l_name)
# Out:
# Please enter your first nameZahire
# Please enter your last nameSeymen
# Hello, Zahire Seymen

# %%
f_name=input('Please enter your first name: ')
l_name=input('Please enter your last name: ')
print('Hello, ' +f_name + ' ' + l_name)
# Out:
# Please enter your first name: Zahire
# Please enter your last name: Seymen
# Hello, Zahire Seymen

# %%
f_name=input('Please enter your first name: ')
l_name=input('Please enter your last name: ')
print('Hello, ' +f_name.upper() + ' ' + l_name.upper())
# Out:
# Please enter your first name: zahire
# Please enter your last name: seymen
# Hello, ZAHIRE SEYMEN

# %%
f_name=input('Please enter your first name: ')
l_name=input('Please enter your last name: ')
print('Hello, ' +f_name.upper() + ' ' + l_name.upper())
# Out:
# Please enter your first name: ahmet senih
# Please enter your last name: seymen
# Hello, AHMET SENIH SEYMEN

# %%
print('www', 'clarusway', "com", sep='.', end=' ')
print('will', end=' ')
print('open', end=' ')
print('your', end=' ')
print('path', end='.')
# Out:
# www.clarusway.com will open your path.

# %%
print("clarusway" + '2020')
# Out:
# clarusway2020

# %%
print("clarusway" + str(2020))
# Out:
# clarusway2020

# %%
x = 12
y = x + 21
x = 2
print(y//x)
# Out:
# 16

# %%
print(0j)
# Out:
# 0j

# %%
0j
# Out:
# 0j

# %%
print(1988+int(number = "32"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-51df1115bd70> in <module>()
# ----> 1 print(1988+int(number = "32"))
#
# TypeError: 'number' is an invalid keyword argument for int()

# %%
print(1988+int('number = "32"'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-d0572778ae23> in <module>()
# ----> 1 print(1988+int('number = "32"'))
#
# ValueError: invalid literal for int() with base 10: 'number = "32"'

# %%
number =''
print(1988+int(number = "32"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-585159997392> in <module>()
#       1 number =''
# ----> 2 print(1988+int(number = "32"))
#
# TypeError: 'number' is an invalid keyword argument for int()

# %%
number = "32"
print(1988+int(number))
# Out:
# 2020

# %%
x = False
y = not x

#Enter the result of evaluating the expression:

not (x and y)
# Out:
# True

# %%
print("{4} {9} {1} {7} {5} {0} {6} {8} {3} {2}".format('while', 'dream', 'work.', 'and', 'Some', 'success', 'others', 'of', 'wake up', 'people'))
# Out:
# Some people dream of success while others wake up and work.

# %%
print(not None or 1)
# Out:
# True

# %%
print("{3} {1} {4}{1}{0}".format('job.', 'a', 'will', 'I', 'find'))
# Out:
# I a findajob.

# %%
print("{3} {2} {4} {1} {0}".format('job.', 'a', 'will', 'I', 'find'))
# Out:
# I will find a job.

# %%
section_3_5 = "python data types and useful operations"
print(section_3_5.title())
# Out:
# Python Data Types And Useful Operations

# %%
print(False or {0} and [])
# Out:
# []

# %%
print(float("140" * int(input("Enter a number:" ))))
Enter a number: 2
# Out:
#   File "<ipython-input-49-921a580b24a7>", line 2
#     Enter a number: 2
#           ^
# SyntaxError: invalid syntax

# %%
print(float("140" * int(input("Enter a number:" ))))
# Out:
# Enter a number:2
# 140140.0

# %%
print(int("5" + "1"))
print(str("5" + "1"))
print("5" + "1")
# Out:
# 51
# 51
# 51

# %%
var1 = "sleep"
var2 = "eat"
var3 = "better"
var4 = "life"
sentence = f"The less you {var1} and {var2}, the {var3} your {var4} will be."
print(sentence)
# Out:
# The less you sleep and eat, the better your life will be.

# %%
city = "SARAJEVO"
text = f"{ city.capitalize()}"
print(text)
# Out:
# Sarajevo

# %%
city = "SARAJEVO"
text = f"I live in {city.capitalize()}"
print(text)
# Out:
# I live in Sarajevo

# %%
city = "SARAJEVO"
text = f"I live in {city.capitalize()}."
print(text)
# Out:
# I live in Sarajevo.

# %%
a = 36.5
b = '30'
c = '3.5'
d = ' F is enough for room temperature.'

print(str(a+int(b)+float(c))+d)
# Out:
# 70.0 F is enough for room temperature.

# %%
color = 'red'  # str type variable
season = 'summer'
price = 250  # int type variable
pi = 3.14  # float type variable
color = 'blue'  # You can always assign a new value to a created variable
price = 100  # value of 'price' is changed
season = 'winter'  

print(color, price, season, sep=', ' )
# Out:
# blue, 100, winter

# %%
print(range.__doc__)
# Out:
# range(stop) -> range object
# range(start, stop[, step]) -> range object
#
# Return an object that produces a sequence of integers from start (inclusive)
# to stop (exclusive) by step.  range(i, j) produces i, i+1, i+2, ..., j-1.
# start defaults to 0, and stop is omitted!  range(4) produces 0, 1, 2, 3.
# These are exactly the valid indices for a list of 4 elements.
# When step is given, it specifies the increment (or decrement).
